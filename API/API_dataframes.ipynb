# %% [markdown]
# # API Notebook

# %%
#  import dependencies

import pandas as pd
import numpy as np
import json
import requests
from config import api_key

# %%
# requesting from api 
 
url = "https://api-nba-v1.p.rapidapi.com/gameDetails/"

headers = {
    'x-rapidapi-host': "api-nba-v1.p.rapidapi.com",
    'x-rapidapi-key': api_key
    }

response = requests.get(url, headers=headers)

response_json = response.json()

print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "message": "Endpoint/gameDetails/ does not exist"
# }

# %%
# creating json file to turn into df

# with open('test.json','w') as f:
#     json.dump(response_json,f)

# %% [markdown]
# I found the last game ID # that contained any data through guessing and process of elimination. Hypothetically, this is the max number of entries that could go into the table, but because the API is limited to 100 requests per day, I am choosing to keep the data frames smaller.

# %%
query_url = url + str(10861)
print(query_url)

q_response = requests.get(query_url,headers=headers).json()

print(json.dumps(q_response,indent=4,sort_keys=True))
# Out:
# https://api-nba-v1.p.rapidapi.com/gameDetails/10861
# {
#     "api": {
#         "filters": [
#             ""
#         ],
#         "game": [
#             {
#                 "EndOfPeriod": "0",
#                 "arena": "Chase Center",
#                 "city": "San Francisco",
#                 "clock": "",
#                 "country": "USA",
#                 "currentPeriod": "4/4",
#                 "endTimeUTC": "2021-10-16T04:16:00.000Z",
#                 "gameDuration": "2:06",
#                 "gameId": "10861",
#                 "hTeam": {
#                     "allStar": "0",
#                     "fullName": "Golden State Warriors",
#                     "leaders": [
#                         {
#                             "name": "Stephen Curry",
#                             "playerId": "124",
#                             "points": "41"
#                         },
#                         {
#                             "name": "Stephen Curry",
#                             "playerId": "124",
#                             "rebounds": "9"
#                         },
#                         {
#                             "assists": "1",
#                             "name": "Stephen Curry",
#                             "playerId": "124"
#                         },
#                         {
#                             "assists": "2",
#                             "name": "Nemanja Bjelica",
#                             "playerId": "55"
#                         },
#                         {
#                             "assists": "3",
#                             "name": "Andre Iguodala",
#                             "playerId": "256"
#                         },
#                         {
#                             "assists": "7",
#                             "name": "Draymond Green",
#                             "playerId": "204"
#                         }
#                     ],
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/de/Warriors_de_Golden_State_logo.svg/1200px-Warriors_de_Golden_State_logo.svg.png",
#                     "nbaFranchise": "1",
#                     "nickname": "Warriors",
#                     "score": {
#                         "linescore": [
#                             "17",
#                             "38",
#                             "43",
#                             "21"
#                         ],
#                         "loss": "0",
#                         "points": "119",
#                         "seriesLoss": "0",
#                         "seriesWin": "2",
#                         "win": "5"
#                     },
#                     "shortName": "GSW",
#                     "teamId": "11"
#                 },
#                 "halftime": "0",
#                 "leadChanges": "",
#                 "league": "standard",
#                 "officials": [
#                     {
#                         "name": "Derek Richardson"
#                     },
#                     {
#                         "name": "Derrick Collins"
#                     },
#                     {
#                         "name": "Brandon Schwab"
#                     }
#                 ],
#                 "seasonStage": "1",
#                 "seasonYear": "2021",
#                 "startTimeUTC": "2021-10-16T02:00:00.000Z",
#                 "statusGame": "Finished",
#                 "statusShortGame": "3",
#                 "timesTied": "",
#                 "vTeam": {
#                     "allStar": "0",
#                     "fullName": "Portland Trail Blazers",
#                     "leaders": [
#                         {
#                             "name": "Norman Powell",
#                             "playerId": "434",
#                             "points": "5"
#                         },
#                         {
#                             "name": "Jusuf Nurkic",
#                             "playerId": "398",
#                             "rebounds": "10"
#                         },
#                         {
#                             "assists": "7",
#                             "name": "Dennis Smith Jr.",
#                             "playerId": "876"
#                         },
#                         {
#                             "name": "CJ McCollum",
#                             "playerId": "347",
#                             "points": "26"
#                         },
#                         {
#                             "assists": "4",
#                             "name": "CJ McCollum",
#                             "playerId": "347"
#                         }
#                     ],
#                     "logo": "https://upload.wikimedia.org/wikipedia/en/thumb/2/21/Portland_Trail_Blazers_logo.svg/1200px-Portland_Trail_Blazers_logo.svg.png",
#                     "nbaFranchise": "1",
#                     "nickname": "Trail Blazers",
#                     "score": {
#                         "linescore": [
#                             "27",
#                             "24",
#                             "26",
#                             "20"
#                         ],
#                         "loss": "4",
#                         "points": "97",
#                         "seriesLoss": "2",
#                         "seriesWin": "0",
#                         "win": "0"
#                     },
#                     "shortName": "POR",
#                     "teamId": "29"
#                 }
#             }
#         ],
#         "message": "GET gameDetails/10861",
#         "results": 1,
#         "status": 200
#     }
# }

# %% [markdown]
# The cells below pull from the API to create dataframes from each of 'gameDetails', 'players/playerId', and 'teams/teamId'. The API-NBA from rapidapi.com is updated semi-regularly, so the code can be run over again to obtain the most recent data.

# %%
# game details info API to calls

details_base_url = "https://api-nba-v1.p.rapidapi.com/gameDetails/"

game_numbers = list(np.random.randint(10861, size=10))
game_numbers

game_info = []
game_not_found = []

for number in game_numbers:
    
    game_url = details_base_url + str(number)

    try:
        game_response = requests.get(game_url,headers=headers).json()

        gameId = game_response['api']['game'][0]['gameId']
        seasonYear = game_response['api']['game'][0]['seasonYear']
        arena = game_response['api']['game'][0]['arena']
        city = game_response['api']['game'][0]['city']
        country = game_response['api']['game'][0]['country']
        startTimeUTC = game_response['api']['game'][0]['startTimeUTC']
        gameDuration = game_response['api']['game'][0]['gameDuration']
        vTeam = game_response['api']['game'][0]['vTeam']['fullName']
        vTeamLeader = game_response['api']['game'][0]['vTeam']['leaders'][0]['playerId']
        awayScore = game_response['api']['game'][0]['vTeam']['score']['points']
        hTeam = game_response['api']['game'][0]['hTeam']['fullName']
        hTeamLeader = game_response['api']['game'][0]['hTeam']['leaders'][0]['playerId']
        homeScore = game_response['api']['game'][0]['hTeam']['score']['points']

        game_info.append({
            'gameId':gameId,
            'seasonYear':seasonYear,
            'arena':arena,
            'city':city,
            'country':country,
            'startTimeUTC Time':startTimeUTC,
            'gameDuration':gameDuration,
            'homeTeam':hTeam,
            'homeScore':homeScore,
            'hTeamLeader':hTeamLeader,
            'awayTeam':vTeam,
            'awayScore':awayScore,
            'vTeamLeader':vTeamLeader
        })

# store any values not found and pass to keep the loop running 
    except:     
        game_not_found.append(gameId)
        pass

# %%
# created 12:23
game_info_df = pd.DataFrame(game_info).set_index('gameId').drop_duplicates()
game_info_df.head(10)
# Out:
#        seasonYear                     arena          city country  \
# gameId
# 7341         2019  American Airlines Center        Dallas     USA
# 8176         2020   Bankers Life Fieldhouse  Indianapolis     USA
# 4881         2018               Moda Center      Portland     USA
# 8401         2020                 TD Garden        Boston     USA
# 6656         2019           Barclays Center      Brooklyn     USA
# 4020         2017         Capital One Arena    Washington     USA
# 3298         2017       Quicken Loans Arena     Cleveland     USA
# 3548         2017           Spectrum Center     Charlotte     USA
# 977          2015
#
#                startTimeUTC Time gameDuration                homeTeam  \
# gameId
# 7341    2020-03-08T23:00:00.000Z         2:11        Dallas Mavericks
# 8176    2021-03-24T23:00:00.000Z         2:19          Indiana Pacers
# 4881    2018-12-24T02:00:00.000Z         2:27  Portland Trail Blazers
# 8401    2021-04-22T23:00:00.000Z         2:06          Boston Celtics
# 6656    2019-11-29T17:00:00.000Z         2:13           Brooklyn Nets
# 4020    2018-03-25T22:00:00.000Z         2:13      Washington Wizards
# 3298    2017-12-10T01:00:00.000Z         2:13     Cleveland Cavaliers
# 3548    2018-01-13T22:00:00.000Z         2:01       Charlotte Hornets
# 977     2016-02-27T01:30:00.000Z         2:40        Dallas Mavericks
#
#        homeScore hTeamLeader               awayTeam awayScore vTeamLeader
# gameId
# 7341         109         963         Indiana Pacers       112         979
# 8176         116         463        Detroit Pistons       111         200
# 4881         121         319       Dallas Mavericks       118          36
# 8401          99         538           Phoenix Suns        86         415
# 6656         112         142         Boston Celtics       107         882
# 4020          97          45        New York Knicks       101          83
# 3298         105         265     Philadelphia 76ers        98         118
# 3548          91         538  Oklahoma City Thunder       101         544
# 977          122         412         Denver Nuggets       116          38

# %%
# players info API calls, 393 active players as of 2020, API contains ~8-9 years of game data,
# made upper limit higher to account for any possible players in that range

players_numbers = list(np.random.randint(2500, size=10))

players_base_url = "https://api-nba-v1.p.rapidapi.com/players/playerId/"

player_info = []
player_not_found = []

for number in players_numbers:
    
    player_url = players_base_url + str(number)

    try:
        player_response = requests.get(player_url,headers=headers).json()
        
        playerId = player_response['api']['players'][0]['playerId']
        firstName = player_response['api']['players'][0]['firstName']
        lastName = player_response['api']['players'][0]['lastName']
        teamId = player_response['api']['players'][0]['teamId']
        country = player_response['api']['players'][0]['country']
        startNBA = player_response['api']['players'][0]['startNba']
        dateOfBirth = player_response['api']['players'][0]['dateOfBirth']
        height = player_response['api']['players'][0]['heightInMeters']
        weight = player_response['api']['players'][0]['weightInKilograms']

        player_info.append({
                'playerId':playerId,
                'firstName':firstName,
                'lastName':lastName,
                'teamId':teamId,
                'country':country,
                'dateOfBirth':dateOfBirth,
                'height':height,
                'weight':weight
        })

# store any values not found and pass to keep the loop running 

    except:
        player_not_found.append(playerId)
        pass

# %%
# created 12:26
players_df = pd.DataFrame(player_info).set_index('playerId').drop_duplicates()
players_df.head()
# Out:
#          firstName   lastName teamId country dateOfBirth height weight
# playerId
# 277          Tyler    Johnson      4     USA  1992-05-07    1.9   84.4
# 220           Gary     Harris     26     USA  1994-09-14   1.93   95.3
# 206       JaMychal      Green      9     USA  1990-06-21   2.03  103.0
# 184           Marc      Gasol     19   Spain  1985-01-29   2.11  115.7
# 298         DANIEL  KOPERBERG   None

# %%
teams_numbers = (np.random.randint(200,size=10))

teams_base_url = "https://api-nba-v1.p.rapidapi.com/teams/teamId/"


teams_info = []

for number in teams_numbers:
    try:
        teams_query_url = teams_base_url + str(number)
    
    # print(teams_query_url)
    # print(api_key)
    
        response = requests.get(teams_query_url,headers=headers).json()
    
        id_teams = (response['api']['teams'][0]['teamId'])
        fName_teams = (response['api']['teams'][0]['fullName'])
        nName_teams = (response['api']['teams'][0]['nickname'])
        sName_teams = (response['api']['teams'][0]['shortName'])
        teams_city = (response['api']['teams'][0]['city'])

    # print(teams_city)

        teams_info.append({
            "TeamID":id_teams,
            "fullName":fName_teams,
            "nickname":nName_teams,
            "shortName":sName_teams,
            "City":teams_city
        })
    except:
        pass

# %%
# created 12:33
teams_df = pd.DataFrame(teams_info).set_index('TeamID').drop_duplicates()
teams_df.head(10)
# Out:
#                      fullName     nickname shortName          City
# TeamID
# 7         Cleveland Cavaliers    Cavaliers       CLE     Cleveland
# 35                Team LeBron  Team LeBron       LBN          Team
# 40                  Utah Jazz         Jazz       UTA          Utah
# 34           Team Team Durant  Team Durant       DRT          Team
# 11      Golden State Warriors     Warriors       GSW  Golden State

# %%
# converting dataframes to csv for loading into sql
game_info_df.to_csv('games_current_data.csv', index=True)
players_df.to_csv('players_current_data.csv', index=True)
teams_df.to_csv('teams_current_data.csv', index=True)
